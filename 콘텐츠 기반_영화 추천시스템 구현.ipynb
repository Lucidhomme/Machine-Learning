# %%
import warnings
warnings.filterwarnings("ignore")
import pandas_datareader.data as web
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False

# %matplotlib inline

from fbprophet import Prophet
from datetime import datetime
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score
import ast

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
# plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
data = pd.read_csv('./data/movies_metadata.csv')

# %%
data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ... release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...   1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...   1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...   1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...   1995-12-22
# 4  Just when George Banks has recovered from his ...  ...   1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
data.shape
# Out:
# (45466, 24)

# %%
#전처리
fix_data = data[['id','genres','vote_average','vote_count','popularity','title','tagline','overview']]

# %%
#모수에 따른 평점 불균형 조정(IMDB 가중치 참고)
# r: 개별영화 평점, v:개별 영화평점에 투표한 횟수, m: 특정순위안에 들어야하는 최소 투표, c:전체 영화평균평점
m = fix_data['vote_count'].quantile(0.99)
fix_data = data.loc[data['vote_count'] >= m]

# %%
fix_data.shape # 500위 안 목표
# Out:
# (455, 24)

# %%
c = fix_data['vote_average'].mean()

# %%
print(c)
print(m)
# Out:
# 6.9958241758241755
# 2183.8199999999924

# %%
def weighted_rating(x, m=m, c=c):
    v = x['vote_count']
    r = x['vote_average']
    return (v / (v+m) * r) + (m / (m+v) * c)

# %%
fix_data['score'] = fix_data.apply(weighted_rating, axis = 1)

# %%
fix_data.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 31  False                                                NaN  29500000
# 46  False                                                NaN  33000000
# 49  False                                                NaN   6000000
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 46  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
#
#                                              homepage    id    imdb_id  \
# 0                http://toystory.disney.com/toy-story   862  tt0114709
# 1                                                 NaN  8844  tt0113497
# 31                                                NaN    63  tt0114746
# 46                         http://www.sevenmovie.com/   807  tt0114369
# 49  http://www.mgm.com/#/our-titles/2083/The-Usual...   629  tt0114814
#
#    original_language      original_title  \
# 0                 en           Toy Story
# 1                 en             Jumanji
# 31                en      Twelve Monkeys
# 46                en               Se7en
# 49                en  The Usual Suspects
#
#                                              overview  ...      revenue  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1   When siblings Judy and Peter discover an encha...  ...  262797249.0
# 31  In the year 2035, convict James Cole reluctant...  ...  168840000.0
# 46  Two homicide detectives are on a desperate hun...  ...  327311859.0
# 49  Held in an L.A. interrogation room, Verbal Kin...  ...   23341568.0
#
#    runtime                                   spoken_languages    status  \
# 0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 31   129.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 46   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 49   106.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...  Released
#
#                                          tagline               title  video  \
# 0                                            NaN           Toy Story  False
# 1      Roll the dice and unleash the excitement!             Jumanji  False
# 31                        The future is history.      Twelve Monkeys  False
# 46         Seven deadly sins. Seven ways to die.               Se7en  False
# 49  Five Criminals. One Line Up. No Coincidence.  The Usual Suspects  False
#
#    vote_average vote_count     score
# 0           7.7     5415.0  7.497627
# 1           6.9     2413.0  6.945523
# 31          7.4     2470.0  7.210339
# 46          8.1     5915.0  7.802263
# 49          8.1     3334.0  7.662994
#
# [5 rows x 25 columns]

# %%
fix_data.shape
# Out:
# (455, 25)

# %%
fix_data[['genres']].head()
# Out:
#                               genres
# 0            Animation Comedy Family
# 1           Adventure Fantasy Family
# 31  Science Fiction Thriller Mystery
# 46            Crime Mystery Thriller
# 49              Drama Crime Thriller

# %%
fix_data['genres'] = fix_data['genres'].apply(ast.literal_eval)

# %%
fix_data[['genres']].head()
# Out:
#                                                genres
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 31  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 46  [{'id': 80, 'name': 'Crime'}, {'id': 9648, 'na...
# 49  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...

# %%
fix_data['genres'] = fix_data['genres'].apply(lambda x : [d['name'] for d in x]).apply(lambda x : " ".join(x))

# %%
fix_data.head()
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   False                                                NaN  65000000
# 31  False                                                NaN  29500000
# 46  False                                                NaN  33000000
# 49  False                                                NaN   6000000
#
#                               genres  \
# 0            Animation Comedy Family
# 1           Adventure Fantasy Family
# 31  Science Fiction Thriller Mystery
# 46            Crime Mystery Thriller
# 49              Drama Crime Thriller
#
#                                              homepage    id    imdb_id  \
# 0                http://toystory.disney.com/toy-story   862  tt0114709
# 1                                                 NaN  8844  tt0113497
# 31                                                NaN    63  tt0114746
# 46                         http://www.sevenmovie.com/   807  tt0114369
# 49  http://www.mgm.com/#/our-titles/2083/The-Usual...   629  tt0114814
#
#    original_language      original_title  \
# 0                 en           Toy Story
# 1                 en             Jumanji
# 31                en      Twelve Monkeys
# 46                en               Se7en
# 49                en  The Usual Suspects
#
#                                              overview  ...      revenue  \
# 0   Led by Woody, Andy's toys live happily in his ...  ...  373554033.0
# 1   When siblings Judy and Peter discover an encha...  ...  262797249.0
# 31  In the year 2035, convict James Cole reluctant...  ...  168840000.0
# 46  Two homicide detectives are on a desperate hun...  ...  327311859.0
# 49  Held in an L.A. interrogation room, Verbal Kin...  ...   23341568.0
#
#    runtime                                   spoken_languages    status  \
# 0     81.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1    104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 31   129.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 46   127.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 49   106.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...  Released
#
#                                          tagline               title  video  \
# 0                                            NaN           Toy Story  False
# 1      Roll the dice and unleash the excitement!             Jumanji  False
# 31                        The future is history.      Twelve Monkeys  False
# 46         Seven deadly sins. Seven ways to die.               Se7en  False
# 49  Five Criminals. One Line Up. No Coincidence.  The Usual Suspects  False
#
#    vote_average vote_count     score
# 0           7.7     5415.0  7.497627
# 1           6.9     2413.0  6.945523
# 31          7.4     2470.0  7.210339
# 46          8.1     5915.0  7.802263
# 49          8.1     3334.0  7.662994
#
# [5 rows x 25 columns]

# %%
#콘텐츠기반 필터링
fix_data.genres.head()
# Out:
# 0              Animation Comedy Family
# 1             Adventure Fantasy Family
# 31    Science Fiction Thriller Mystery
# 46              Crime Mystery Thriller
# 49                Drama Crime Thriller
# Name: genres, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
count_vector = CountVectorizer(ngram_range=(1,3)) #벡터화

# %%
c_vector_genres = count_vector.fit_transform(fix_data['genres'])

# %%
c_vector_genres.shape
# Out:
# (455, 354)

# %%
from sklearn.metrics.pairwise import cosine_similarity
#코사인 유사도를 구한 벡터를 미리 저장
genre_c_sim = cosine_similarity(c_vector_genres, c_vector_genres).argsort()[:,::-1]

# %%
genre_c_sim.shape
# Out:
# (455, 455)

# %%
def get_recommend_movie_list(df, movie_title, top=30):
    # 특정 영화와 비슷한 영화를 추천해야 하기때문에 특정 영화정보를 추출
    target_movie_index = df[df['title'] == movie_title].index.values
    
    # 코사인 유사도 중 비슷한 코사인 유사도를 가진 정보를 추출
    sim_index = genre_c_sim[target_movie_index, :top].reshape(-1)
    
    # 본인을 제외
    sim_index = sim_index[sim_index != target_movie_index]
    
    # 데이터프레임으로 만들고 vote_count로 정렬한 뒤 리턴
    result = df.iloc[sim_index].sort_values('score', ascending=False)[:10]
    return result

# %%
get_recommend_movie_list(fix_data, movie_title='Toy Story') #토이스토리와 비슷한 장르의 영화 추천
# Out:
#        adult                              belongs_to_collection     budget  \
# 13724  False                                                NaN  175000000
# 6232   False  {'id': 137697, 'name': 'Finding Nemo Collectio...   94000000
# 15348  False  {'id': 10194, 'name': 'Toy Story Collection', ...  200000000
# 4756   False  {'id': 137696, 'name': 'Monsters, Inc. Collect...  115000000
# 23557  False  {'id': 89137, 'name': 'How to Train Your Drago...  145000000
# 11567  False                                                NaN  150000000
# 22718  False  {'id': 325470, 'name': 'The Lego Movie Collect...   60000000
# 16130  False  {'id': 463959, 'name': 'Tangled Collection', '...  260000000
# 4178   False  {'id': 2150, 'name': 'Shrek Collection', 'post...   60000000
# 2997   False  {'id': 10194, 'name': 'Toy Story Collection', ...   90000000
#
#                                                  genres  \
# 13724                 Animation Comedy Family Adventure
# 6232                                   Animation Family
# 15348                           Animation Family Comedy
# 4756                            Animation Comedy Family
# 23557  Fantasy Action Adventure Animation Comedy Family
# 11567                   Animation Comedy Family Fantasy
# 22718         Adventure Animation Comedy Family Fantasy
# 16130                                  Animation Family
# 4178          Adventure Animation Comedy Family Fantasy
# 2997                            Animation Comedy Family
#
#                                                homepage      id    imdb_id  \
# 13724           http://disney.go.com/disneypictures/up/   14160  tt1049413
# 6232              http://movies.disney.com/finding-nemo      12  tt0266543
# 15348                    http://disney.go.com/toystory/   10193  tt0435761
# 4756              http://movies.disney.com/monsters-inc     585  tt0198781
# 23557              http://www.howtotrainyourdragon.com/   82702  tt1646971
# 11567  http://disney.go.com/disneypictures/ratatouille/    2062  tt0382932
# 22718                       http://www.thelegomovie.com  137106  tt1490017
# 16130      http://disney.go.com/disneypictures/tangled/   38757  tt0398286
# 4178                              http://www.shrek.com/     808  tt0126029
# 2997             http://toystory.disney.com/toy-story-2     863  tt0120363
#
#       original_language              original_title  \
# 13724                en                          Up
# 6232                 en                Finding Nemo
# 15348                en                 Toy Story 3
# 4756                 en              Monsters, Inc.
# 23557                en  How to Train Your Dragon 2
# 11567                en                 Ratatouille
# 22718                en              The Lego Movie
# 16130                en                     Tangled
# 4178                 en                       Shrek
# 2997                 en                 Toy Story 2
#
#                                                 overview  ...       revenue  \
# 13724  Carl Fredricksen spent his entire life dreamin...  ...  7.350991e+08
# 6232   Nemo, an adventurous young clownfish, is unexp...  ...  9.403355e+08
# 15348  Woody, Buzz, and the rest of Andy's toys haven...  ...  1.066970e+09
# 4756   James Sullivan and Mike Wazowski are monsters,...  ...  5.628163e+08
# 23557  The thrilling second chapter of the epic How T...  ...  6.091230e+08
# 11567  A rat named Remy dreams of becoming a great Fr...  ...  6.237228e+08
# 22718  An ordinary Lego mini-figure, mistakenly thoug...  ...  4.691607e+08
# 16130  When the kingdom's most wanted-and most charmi...  ...  5.917949e+08
# 4178   It ain't easy bein' green -- especially if you...  ...  4.844092e+08
# 2997   Andy heads off to Cowboy Camp, leaving his toy...  ...  4.973669e+08
#
#       runtime                                   spoken_languages    status  \
# 13724    96.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6232    100.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 15348   103.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4756     92.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 23557   102.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 11567   111.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 22718   100.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 16130   100.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4178     90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2997     92.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                  tagline  \
# 13724                                                NaN
# 6232   There are 3.7 trillion fish in the ocean. They...
# 15348                           No toy gets left behind.
# 4756                           We Scare Because We Care.
# 23557                              The training is over.
# 11567                       He's dying to become a chef.
# 22718         The story of a nobody who saved everybody.
# 16130           They're taking adventure to new lengths.
# 4178                 The greatest fairy tale never told.
# 2997                                  The toys are back!
#
#                             title  video vote_average vote_count     score
# 13724                          Up  False          7.8     7048.0  7.609769
# 6232                 Finding Nemo  False          7.6     6292.0  7.444332
# 15348                 Toy Story 3  False          7.6     4710.0  7.408610
# 4756               Monsters, Inc.  False          7.5     6150.0  7.367884
# 23557  How to Train Your Dragon 2  False          7.6     3163.0  7.353234
# 11567                 Ratatouille  False          7.5     4510.0  7.335516
# 22718              The Lego Movie  False          7.5     3127.0  7.292682
# 16130                     Tangled  False          7.4     3419.0  7.242464
# 4178                        Shrek  False          7.3     4183.0  7.195668
# 2997                  Toy Story 2  False          7.3     3914.0  7.191065
#
# [10 rows x 25 columns]
